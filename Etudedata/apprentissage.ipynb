# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Lecture d un fichier csv au niveau de la ligne un grace a import et grace a read_extension du fichier on lit les elements du fichier

# %%
df=pd.read_csv("Smartphones_cleaned_dataset.csv")

# %% [markdown]
# df

# %%
#Analyse du dataset de smartphone

# %%
df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
# 2           False          exynos        8.0              2.4  ...
# 3           False      snapdragon        8.0              2.2  ...
# 4           False       dimensity        8.0              2.6  ...
#
#    refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0           120                 3                1.0  android
# ...

# %%
df.tail()
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 975    False           False      snapdragon        8.0             3.00  ...
# 976    False           False      snapdragon        8.0             2.20  ...
# 977     True            True       dimensity        8.0             2.85  ...
# 978     True           False      snapdragon        8.0             2.20  ...
# 979    False           False             NaN        8.0              NaN  ...
#
#      refresh_rate  num_rear_cameras  num_front_cameras       os  \
# ...

# %%
df.shape 
#permet de connaitre le nombre de lignes et de colones du dataset
# Out:
# (980, 26)

# %%
df.columns.tolist()
#Renvoie les columns sous forme de liste . df.columns affiche les colones et tolists creer une liste
# Out:
# ['brand_name',
#  'model',
#  'price',
#  'rating',
#  'has_5g',
#  'has_nfc',
#  'has_ir_blaster',
#  'processor_brand',
#  'num_cores',
#  'processor_speed',
#  'battery_capacity',
#  'fast_charging_available',
#  'fast_charging',
#  'ram_capacity',
#  'internal_memory',
#  'screen_size',
#  'refresh_rate',
#  'num_rear_cameras',
#  'num_front_cameras',
#  'os',
#  'primary_camera_rear',
#  'primary_camera_front',
#  'extended_memory_available',
#  'extended_upto',
#  'resolution_width',
#  'resolution_height']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=980, step=1)

# %%
#selectionner des donnees d une colone
df["price"].head()
# Out:
# 0    54999
# 1    19989
# 2    16499
# 3    14999
# 4    24999
# Name: price, dtype: int64

# %%
type(df.price)
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[10:20]
#permet de recuperer des elements dans un interval excluant le dernier element
# Out:
#    brand_name                         model   price  rating  has_5g  has_nfc  \
# 10     realme                 Realme 10 Pro   18999    82.0    True    False
# 11       oppo                      Oppo A78   18999    79.0    True     True
# 12     xiaomi   Xiaomi Redmi Note 12 Pro 5G   24762    79.0    True    False
# 13       vivo  Vivo T1 5G (6GB RAM + 128GB)   16990    80.0    True    False
# 14    samsung   Samsung Galaxy S23 Ultra 5G  114990     NaN    True     True
# 15      apple               Apple iPhone 13   62999    79.0    True     True
# 16       vivo                      Vivo Y16    9999    65.0   False    False
# 17       oppo          OPPO Reno 9 Pro Plus   45999    86.0    True     True
# 18    oneplus                OnePlus 10R 5G   32999    86.0    True     True
# 19       vivo                      Vivo Y22   14499    72.0   False    False
#
#     has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
df.loc[10:20]
#permet de recuperer des elements dans un interval sans exclure le dernier element
# Out:
#    brand_name                         model   price  rating  has_5g  has_nfc  \
# 10     realme                 Realme 10 Pro   18999    82.0    True    False
# 11       oppo                      Oppo A78   18999    79.0    True     True
# 12     xiaomi   Xiaomi Redmi Note 12 Pro 5G   24762    79.0    True    False
# 13       vivo  Vivo T1 5G (6GB RAM + 128GB)   16990    80.0    True    False
# 14    samsung   Samsung Galaxy S23 Ultra 5G  114990     NaN    True     True
# 15      apple               Apple iPhone 13   62999    79.0    True     True
# 16       vivo                      Vivo Y16    9999    65.0   False    False
# 17       oppo          OPPO Reno 9 Pro Plus   45999    86.0    True     True
# 18    oneplus                OnePlus 10R 5G   32999    86.0    True     True
# 19       vivo                      Vivo Y22   14499    72.0   False    False
# 20    oneplus                   OnePlus 11R   39999    85.0    True     True
#
# ...

# %%
df_prix = df.set_index("price")

# %%
#df_prix.loc[18999].values.tolist()

# %%
df["brand_name"]== "samsung"
# cette ligne permet d obtenir un booleen , les brandname qui sont samsung sont true et sinon cest false
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 975    False
# 976    False
# 977    False
# 978    False
# 979     True
# Name: brand_name, Length: 980, dtype: bool

# %%
df[df["brand_name"]== "samsung"]
#ici on affiche toutes les informations des brandname qui sont samsung cest le filtrage comme dans Excel mais en codage
# Out:
#     brand_name                                    model   price  rating  \
# 2      samsung                    Samsung Galaxy A14 5G   16499    75.0
# 5      samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)   16999    80.0
# 14     samsung              Samsung Galaxy S23 Ultra 5G  114990     NaN
# 25     samsung                 Samsung Galaxy S20 FE 5G   31239    88.0
# 34     samsung                    Samsung Galaxy M53 5G   23790    85.0
# ..         ...                                      ...     ...     ...
# 940    samsung    Samsung Galaxy A21s (6GB RAM + 128GB)   17499    75.0
# 952    samsung                       Samsung Galaxy A11    9990    63.0
# 955    samsung             Samsung Galaxy A9 Pro (2019)   39990    78.0
# 956    samsung                 Samsung Galaxy A7 (2018)   21490    70.0
# 979    samsung                   Samsung Galaxy M52s 5G   24990    74.0
#
#      has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# ...

# %%
filtre_brandname = df["brand_name"].isin(["samsung","xiomi"])
df[filtre_brandname]
#isin permet d emettre plusieurs elements en recherche dans une serie sachant qu une serie est une colone du dataset
# Out:
#     brand_name                                    model   price  rating  \
# 2      samsung                    Samsung Galaxy A14 5G   16499    75.0
# 5      samsung  Samsung Galaxy F23 5G (6GB RAM + 128GB)   16999    80.0
# 14     samsung              Samsung Galaxy S23 Ultra 5G  114990     NaN
# 25     samsung                 Samsung Galaxy S20 FE 5G   31239    88.0
# 34     samsung                    Samsung Galaxy M53 5G   23790    85.0
# ..         ...                                      ...     ...     ...
# 940    samsung    Samsung Galaxy A21s (6GB RAM + 128GB)   17499    75.0
# 952    samsung                       Samsung Galaxy A11    9990    63.0
# 955    samsung             Samsung Galaxy A9 Pro (2019)   39990    78.0
# 956    samsung                 Samsung Galaxy A7 (2018)   21490    70.0
# 979    samsung                   Samsung Galaxy M52s 5G   24990    74.0
#
#      has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# ...

# %%
#Le but de cette partie est d apprendre a modifier les valeurs d une serie parexemple si je veux remplacer tout les M par A , normalement dans Excel j aurai fais une recherche avec ctl+H et changer mais ici ce nest pas ca 
# je vais d abord copier tout le dataset dans une variable avec la fonction copy() et ensuite modifier la valeur qu on veut dans le dataset copier 
# On verra aussi comment convertir types des valeurs d une serie exemple les string en float

cop = df.copy()
#cop.price = cop.price.apply(lambda x: x.replace("val a remlacer", "valeursouhaiter")) on utilise apply et  lambda uniquement lorsque la val a changer est un string
cop.price = cop.price.replace(9, 8)
#cop.rating = cop.rating.astype(int) cette ligne est incorrect car dans le dataframe certains rating ont pour valeur NAN et donc ne peuvent etre converti en integer
#il faut don copier le dataset et faire  conversions sur le dataset copier
secondecopie = df.copy()
secondecopie['rating'] = secondecopie['rating'].fillna(0).astype(int)
#fillna permet de remplacer les valeurs NAN par une valeur que l on choisi et astype c est pour convertir les type
#secondecopie = secondecopie.dropna(subset=['rating']) cette ligne va supprimer toutes les lignes du tableau qui possedent dans la serie rating la velur NAN grace a DROPNA
#secondecopie['rating'] = secondecopie['rating'].astype('Int64') cette ligne converti en un type d entier qui pre nd en compte les NAN et les vides

# %%
secondecopie.rating
# Out:
# 0      89
# 1      81
# 2      75
# 3      81
# 4      82
#        ..
# 975    83
# 976    75
# 977    85
# 978    80
# 979    74
# Name: rating, Length: 980, dtype: int64

# %%
secondecopie[secondecopie["rating"]>=85]
#cette ligne filtre les donnees en fonctionde la condition que j ai mis
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999      89    True
# 7       xiaomi    Xiaomi Redmi Note 12 Pro Plus  29999      86    True
# 8      nothing                  Nothing Phone 1  26749      85    True
# 17        oppo             OPPO Reno 9 Pro Plus  45999      86    True
# 18     oneplus                   OnePlus 10R 5G  32999      86    True
# ..         ...                              ...    ...     ...     ...
# 967     xiaomi                        Xiaomi 14  54999      89    True
# 968   motorola              Motorola ThinkPhone  49990      89    True
# 969     xiaomi                    Xiaomi Civi 3  32990      86    True
# 971       oppo                     Oppo Find X6  69990      89    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990      85    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
df.drop("extended_memory_available", axis=1, inplace=True)

# %%
df
# Out:
#     brand_name                            model  price  rating  has_5g  \
# 0      oneplus                    OnePlus 11 5G  54999    89.0    True
# 1      oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0    True
# 2      samsung            Samsung Galaxy A14 5G  16499    75.0    True
# 3     motorola             Motorola Moto G62 5G  14999    81.0    True
# 4       realme               Realme 10 Pro Plus  24999    82.0    True
# ..         ...                              ...    ...     ...     ...
# 975   motorola       Motorola Moto Edge S30 Pro  34990    83.0    True
# 976      honor                      Honor X8 5G  14990    75.0    True
# 977       poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0    True
# 978   motorola             Motorola Moto G91 5G  19990    80.0    True
# 979    samsung           Samsung Galaxy M52s 5G  24990    74.0    True
#
#      has_nfc  has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# ...

# %%
df.set_index("num_front_cameras", inplace=True)

# %%
df
# Out:
#                   brand_name                            model  price  rating  \
# num_front_cameras
# 1.0                  oneplus                    OnePlus 11 5G  54999    89.0
# 1.0                  oneplus        OnePlus Nord CE 2 Lite 5G  19989    81.0
# 1.0                  samsung            Samsung Galaxy A14 5G  16499    75.0
# 1.0                 motorola             Motorola Moto G62 5G  14999    81.0
# 1.0                   realme               Realme 10 Pro Plus  24999    82.0
# ...                      ...                              ...    ...     ...
# 1.0                 motorola       Motorola Moto Edge S30 Pro  34990    83.0
# 1.0                    honor                      Honor X8 5G  14990    75.0
# 1.0                     poco  POCO X4 GT 5G (8GB RAM + 256GB)  28990    85.0
# 1.0                 motorola             Motorola Moto G91 5G  19990    80.0
# 1.0                  samsung           Samsung Galaxy M52s 5G  24990    74.0
#
# ...

# %%
#df.drop(1.0, axis=0,inplace=True)
df.head()
# Out:
#                   brand_name                           model  price  rating  \
# num_front_cameras
# NaN                     oppo                Oppo Find N Fold  99990     NaN
# 2.0                     vivo  Vivo V23 5G (12GB RAM + 256GB)  27994    86.0
# 2.0                     vivo                     Vivo V23 5G  24994    83.0
# 2.0                     oppo                 Oppo Find N2 5G  94990     NaN
# 2.0                     vivo                 Vivo V23 Pro 5G  31994    85.0
#
#                    has_5g  has_nfc  has_ir_blaster processor_brand  num_cores  \
# num_front_cameras
# NaN                  True     True           False      snapdragon        8.0
# 2.0                  True    False           False       dimensity        8.0
# 2.0                  True    False           False       dimensity        8.0
# 2.0                  True     True           False      snapdragon        8.0
# 2.0                  True    False           False       dimensity        8.0
#
# ...

# %%
df[df.num_cores==2.0]
# Out:
# Empty DataFrame
# Columns: [brand_name, model, price, rating, has_5g, has_nfc, has_ir_blaster, processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, os, primary_camera_rear, primary_camera_front, extended_upto, resolution_width, resolution_height]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.isnull()
# Out:
#                    brand_name  model  price  rating  has_5g  has_nfc  \
# num_front_cameras
# NaN                     False  False  False    True   False    False
# 2.0                     False  False  False   False   False    False
# 2.0                     False  False  False   False   False    False
# 2.0                     False  False  False    True   False    False
# 2.0                     False  False  False   False   False    False
# 2.0                     False  False  False   False   False    False
# 2.0                     False  False  False    True   False    False
# 2.0                     False  False  False   False   False    False
# 2.0                     False  False  False   False   False    False
# 2.0                     False  False  False   False   False    False
# 2.0                     False  False  False   False   False    False
# 2.0                     False  False  False   False   False    False
# ...

# %%
df[df["rating"].notnull()]
# Out:
#                   brand_name                                 model   price  \
# num_front_cameras
# 2.0                     vivo        Vivo V23 5G (12GB RAM + 256GB)   27994
# 2.0                     vivo                           Vivo V23 5G   24994
# 2.0                     vivo                       Vivo V23 Pro 5G   31994
# 2.0                     vivo                             Vivo Y100   29990
# 2.0                     vivo                          Vivo V21 Pro   32999
# 2.0                   google                        Google Pixel 4   20120
# 2.0                  samsung               Samsung Galaxy S10 Plus   42999
# 2.0                   realme  Realme X50 Pro 5G (12GB RAM + 256GB)   27999
# 2.0                     vivo    Vivo V23 Pro 5G (12GB RAM + 256GB)   36994
# 2.0                    tecno                       Tecno Phantom X   25999
# 2.0                  samsung               Samsung Galaxy Z Fold 3  110999
# ...

# %%
#Dropna() supprime tout les anges qui ont la valeur NAN
#fullna(valeur) remplace toutes les ranges ou se trouve la valeur nlle par unve valeur que l'on definit

# %%
#CALCUL DANS LE DATAFRAME

# %%
df.dtypes
# Out:
# brand_name                  object
# model                       object
# price                        int64
# rating                     float64
# has_5g                        bool
# has_nfc                       bool
# has_ir_blaster                bool
# processor_brand             object
# num_cores                  float64
# processor_speed            float64
# battery_capacity           float64
# fast_charging_available      int64
# fast_charging              float64
# ram_capacity                 int64
# internal_memory              int64
# screen_size                float64
# refresh_rate                 int64
# os                          object
# primary_camera_rear        float64
# primary_camera_front       float64
# extended_upto              float64
# resolution_width             int64
# resolution_height            int64
# dtype: object

# %%
df["price"].describe()
# Out:
# count        33.000000
# mean      65142.515152
# std       58243.698580
# min        4787.000000
# 25%       25999.000000
# 50%       32990.000000
# 75%       94990.000000
# max      214990.000000
# Name: price, dtype: float64

# %%
df["price"].sum()
# Out:
# 2149703

# %%
df["brand_name"].value_counts(normalize=True)
# Out:
# vivo        0.272727
# samsung     0.121212
# huawei      0.121212
# oppo        0.090909
# realme      0.090909
# xiaomi      0.090909
# tecno       0.060606
# motorola    0.060606
# honor       0.030303
# google      0.030303
# itel        0.030303
# Name: brand_name, dtype: float64

# %%
df.groupby("brand_name")["price"].mean()
# Out:
# brand_name
# google       20120.000000
# honor        94990.000000
# huawei      134242.500000
# itel          4787.000000
# motorola     36240.000000
# oppo         71323.333333
# realme       22496.000000
# samsung     118244.000000
# tecno        24499.000000
# vivo         39327.222222
# xiaomi       87659.666667
# Name: price, dtype: float64

# %%
#definition des series de valeurs des abscisses et des ordonness
x = df["brand_name"].values
y = df["price"].values
plt.plot(x,y)
plt.title("courbe des prix des smartphones depuis 2013")
plt.xlabel("marque")# icic c est la titre des abscisses
plt.ylabel("prix")#ici le titre des ordonees
plt.xticks(rotation=45)  # pour incliner les dates
plt.tight_layout()
plt.show()
# Utilisation de matplolib pour creer un graphique de type ligne

# %%
#affichage des prix moyens des smartphones en fonction des mmarques grace au graphique de type bar
# on calcul donc les moyennes des prix de chaque marque et nom de tout l ensemble des marques confondus et sort_values sert a trier de manieres ascendant
prix_moyen = df.groupby("brand_name")["price"].mean().sort_values(ascending=True)
plt.bar(prix_moyen.index,prix_moyen.values)
plt.title('nnnnnnn')
plt.xlabel('marques')
plt.ylabel('prix moyen par marque')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#ressortir la relation entre deux variables grace au graphique de type scatter
# on calcul donc les moyennes des prix de chaque marque et nom de tout l ensemble des marques confondus et sort_values sert a trier de manieres ascendant
x = df["brand_name"].values
y = df["price"].values
plt.plot(x,y)
plt.scatter(x,y)
plt.title('nnnnnnn')
plt.xlabel('marques')
plt.ylabel('prix moyen par marque')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#ressortir la relation entre deux variables grace au graphique de type scatter
# on calcul donc les moyennes des prix de chaque marque et nom de tout l ensemble des marques confondus et sort_values sert a trier de manieres ascendant
x = df["brand_name"].values
y = df["price"].values
plt.plot(x,y)
plt.scatter(x,y)
plt.title('nnnnnnn')
plt.xlabel('marques')
plt.ylabel('prix moyen par marque')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
